# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("r.csv")

# %%
df
# Out:
#       Unnamed: 0              DATE  \
# 0            NaN  1970-01-16 02:11
# 1            NaN  1970-01-16 14:09
# 2            NaN  1970-01-15 02:36
# 3            NaN  1970-01-16 03:18
# 4            NaN  1970-01-16 15:12
# ...          ...               ...
# 2969         NaN  1970-01-14 09:14
# 2970         NaN  1970-01-16 14:57
# 2971         NaN  1970-01-16 06:41
# 2972         NaN  1970-01-16 03:25
# 2973         NaN  1970-01-15 23:52
#
#                                            ProfileName  \
# 0                                           delmartian
# 1                                               dll pa
# 2                      Natalia Corres "Natalia Corres"
# 3                                                 Karl
# 4                        Michael D. Bigham "M. Wassir"
# ...                                                ...
# 2969                                         Maypuppet
# 2970                     B. Rosenberg "unabashed geek"
# ...

# %%
import re
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\agam.c\AppData\Roaming\nltk_data...
# True

# %%
(df['Text'].to_string(index=False))
# Out:
# 'I have bought several of the Vitality canned do...\nProduct arrived labeled as Jumbo Salted Peanuts...\nThis is a confection that has been around a few...\nIf you are looking for the secret ingredient in...\nGreat taffy at a great price.  There was a wide...\nI got a wild hair for taffy and ordered this fi...\nThis saltwater taffy had great flavors and was ...\nThis taffy is so good.  It is very soft and che...\nRight now I\'m mostly just sprouting this so my ...\nThis is a very healthy dog food. Good for their...\nI don\'t know if it\'s the cactus or the tequila ...\nOne of my boys needed to lose some weight and t...\nMy cats have been happily eating Felidae Platin...\ngood flavor! these came securely packed... they...\nThe Strawberry Twizzlers are my guilty pleasure...\nMy daughter loves twizzlers and this shipment o...\nI love eating them and they are good for watchi...\nI am very satisfied with my Twizzler purchase. ...\nTwizzlers, Strawberry my childhood favorite can...\nCandy 
# ...

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sentiments=SentimentIntensityAnalyzer()
df['positive']=[sentiments.polarity_scores(i) ['pos'] for i in df['Text']]
df['negative']=[sentiments.polarity_scores(i) ['neg'] for i in df['Text']]
df['neutral']=[sentiments.polarity_scores(i) ['neu'] for i in df['Text']]

# %%
df
# Out:
#       Unnamed: 0              DATE  \
# 0            NaN  1970-01-16 02:11
# 1            NaN  1970-01-16 14:09
# 2            NaN  1970-01-15 02:36
# 3            NaN  1970-01-16 03:18
# 4            NaN  1970-01-16 15:12
# ...          ...               ...
# 2969         NaN  1970-01-14 09:14
# 2970         NaN  1970-01-16 14:57
# 2971         NaN  1970-01-16 06:41
# 2972         NaN  1970-01-16 03:25
# 2973         NaN  1970-01-15 23:52
#
#                                            ProfileName  \
# 0                                           delmartian
# 1                                               dll pa
# 2                      Natalia Corres "Natalia Corres"
# 3                                                 Karl
# 4                        Michael D. Bigham "M. Wassir"
# ...                                                ...
# 2969                                         Maypuppet
# 2970                     B. Rosenberg "unabashed geek"
# ...

# %%
dff=df.sample(n=1000)

# %%
dff
# Out:
#       Unnamed: 0              DATE                ProfileName  \
# 732          NaN  1970-01-15 01:30               Dissapointed
# 1207         NaN  1970-01-14 04:52      Amy in SC "Amy in SC"
# 1486         NaN  1970-01-15 11:28  Minnie Mouse "single mom"
# 2772         NaN  1970-01-16 11:57                      Sandu
# 229          NaN  1970-01-16 10:45             Victoria Brown
# ...          ...               ...                        ...
# 1371         NaN  1970-01-16 14:38                       djin
# 2281         NaN  1970-01-16 07:40               A. Hannegraf
# 1417         NaN  1970-01-16 11:41                         FU
# 617          NaN  1970-01-16 06:02                Arthur Kang
# 301          NaN  1970-01-16 12:10               longlivedave
#
#                                                    Text  positive  negative  \
# 732   Expiration date 1-13. Smashed and. stale. edib...     0.106     0.109
# ...

# %%
dff.loc[:,'negative']
# Out:
# 732     0.109
# 1207    0.131
# 1486    0.020
# 2772    0.018
# 229     0.025
#         ...
# 1371    0.000
# 2281    0.000
# 1417    0.235
# 617     0.000
# 301     0.148
# Name: negative, Length: 1000, dtype: float64

# %%
dff['negative'].loc[dff.index[0]]
# Out:
# 0.109

# %%
count=0
for i in range (1000):
    if dff['negative'].loc[dff.index[i]] > dff['positive'].loc[dff.index[i]] and dff['negative'].loc[dff.index[i]]>0.1:
        count+=1
print (count)
# Out:
# 85

# %%
if count<=100:
    print("product is good")
elif count>100 and count>=300:
       print("product is average")
else:
    print("product is below average")
# Out:
# product is good
